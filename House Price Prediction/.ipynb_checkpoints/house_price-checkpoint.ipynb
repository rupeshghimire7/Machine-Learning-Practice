# %% [markdown]
# # House Price Prediction

# %% [markdown]
# **Importing TF**

# %%
import tensorflow_decision_forests as tfdf
import pandas as pd

import tensorflow as tf

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
print("TensorFlow v" + tf.__version__)
print("TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# TensorFlow v2.12.0
# TensorFlow Decision Forests v1.3.0

# %% [markdown]
# ### Loading Datasets

# %%
train_df = pd.read_csv('train.csv')

# %%
print(train_df.shape)
train_df.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
#  Out of 81 columns, one is id and another is target variable so there are 79 features and 1460 instances of data.

# %%
train_df.drop('Id',axis=1,inplace=True)
train_df.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
#
# [2 rows x 80 columns]

# %% [markdown]
# Inspecitng our given dataset:

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# It seems to have three data types: int64, float64, object

# %% [markdown]
# Inspecting **Target Values**

# %%
train_df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# sns.displot(train_df['SalePrice'],kde=True, bins=100)

# %% [markdown]
# **Numerical Features** extraction

# %%
num_df = train_df.select_dtypes(include = ['float64', 'int64'])
num_df.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# Now we have 37 numerical columns in num_df dataframe.

# %%
num_df.hist(figsize=(20,20),bins=25,xlabelsize=8,ylabelsize=8);

# %% [markdown]
# **Data Preparation**
#
# This dataset contains a mix of numeric, categorical and missing features. TF-DF supports all these feature types natively, and no preprocessing is required. This is one advantage of tree-based models, making them a great entry point to Tensorflow and ML.

# %%
# df_train = pd.read_csv('train.csv')
# df_test = pd.read_csv('test.csv')
# dataset = pd.concat([df_train,df_test], ignore_index=True)
# dataset.reset_index(drop=True,inplace=True)
# dataset.drop('Id',axis=1,inplace=True)
# print(dataset.shape)
# dataset.head(2)
# Out:
# (2919, 80)
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal   208500.0
# 1       0      5    2007        WD         Normal   181500.0
#
# [2 rows x 80 columns]

# %% [markdown]
# Dataset splitting

# %%
import numpy as np

def split_dataset(dataset, test_ratio=0.30):
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

train_ds_pd, valid_ds_pd = split_dataset(train_df)
print("{} examples in Training Set, {} examples in Validation set.".format(
    len(train_ds_pd), len(valid_ds_pd)))
# Out:
# 1008 examples in Training Set, 452 examples in Validation set.

# %% [markdown]
# By default the Random Forest Model is configured to train classification tasks. Since this is a regression problem, we will **specify the type of the task** (tfdf.keras.Task.REGRESSION) as a parameter here.

# %%
label = 'SalePrice'
train_ds_tf = tfdf.keras.pd_dataframe_to_tf_dataset(train_ds_pd, label=label, task = tfdf.keras.Task.REGRESSION)
valid_ds_tf = tfdf.keras.pd_dataframe_to_tf_dataset(valid_ds_pd, label=label, task = tfdf.keras.Task.REGRESSION)

# %% [markdown]
# **Selecting A Model: Decision Forest Based Model**

# %%
tfdf.keras.get_all_models()
# Out:
# [tensorflow_decision_forests.keras.RandomForestModel,
#  tensorflow_decision_forests.keras.GradientBoostedTreesModel,
#  tensorflow_decision_forests.keras.CartModel,
#  tensorflow_decision_forests.keras.DistributedGradientBoostedTreesModel]

# %% [markdown]
# To start, we'll work with a Random Forest. This is the most well-known of the Decision Forest training algorithms.
#
# A Random Forest is an ensemble of decision trees, each trained independently on a random subset of the training dataset (sampled with replacement called bootstraping method of sampling). The algorithm is unique in that it is robust to overfitting, and easy to use.

# %%
rf = tfdf.keras.RandomForestModel(task = tfdf.keras.Task.REGRESSION)
rf.compile(metrics=["mse"])
# Out:
# Use /tmp/tmppihij_ty as temporary training directory

# %% [markdown]
# **Model Training**

# %%
rf.fit(x=train_ds_tf)
# Out:
# Reading training dataset...
# 2023-05-28 22:32:55.812031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_77' with dtype int64 and shape [1008]
# 	 [[{{node Placeholder/_77}}]]
# Training dataset read in 0:00:11.719526. Found 1008 examples.
# Training model...
# [INFO 23-05-28 22:33:08.2747 +0545 kernel.cc:1242] Loading model from path /tmp/tmppihij_ty/model/ with prefix faed431e34b4491d
# Model trained in 0:00:01.416232
# Compiling model...
# [INFO 23-05-28 22:33:08.7777 +0545 decision_forest.cc:660] Model loaded with 300 root(s), 95768 node(s), and 73 input feature(s).
# [INFO 23-05-28 22:33:08.7778 +0545 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 23-05-28 22:33:08.7778 +0545 kernel.cc:1074] Use fast generic engine
# ...

# %% [markdown]
# We can also use Out of bag (OOB) score to validate our RandomForestModel. To train a Random Forest Model, a set of random samples from training set are choosen by the algorithm and the rest of the samples are used to finetune the model.The subset of data that is not chosen is known as Out of bag data (OOB). OOB score is computed on the OOB data.
#
# OOB validation set is in ```valid_ds_tf```
#
# The training logs show the Root Mean Squared Error (RMSE) evaluated on the out-of-bag dataset according to the number of trees in the model. Let us plot this.

# %%
import matplotlib.pyplot as plt
logs = rf.make_inspector().training_logs()
plt.plot([log.num_trees for log in logs], [log.evaluation.rmse for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("RMSE (out-of-bag)")
plt.show()

# %% [markdown]
# OOB STATS:

# %%
inspector = rf.make_inspector()
inspector.evaluation()
# Out:
# Evaluation(num_examples=1008, accuracy=None, loss=None, rmse=28038.182475725487, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
evaluation = rf.evaluate(x=valid_ds_tf,return_dict=True)

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 2023-05-28 22:39:04.977928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_49' with dtype double and shape [452]
# 	 [[{{node Placeholder/_49}}]]
# 1/1 [==============================] - 1s 513ms/step - loss: 0.0000e+00 - mse: 1061600896.0000
# loss: 0.0000
# mse: 1061600896.0000

# %% [markdown]
# **Variable Importance**

# %% [markdown]
# Variable importances generally indicate how much a feature contributes to the model predictions or quality. There are several ways to identify important features using TensorFlow Decision Forests. Let us list the available Variable Importances for Decision Trees:

# %%
print(f"Available variable importances:")
for importance in inspector.variable_importances().keys():
  print("\t", importance)
# Out:
# Available variable importances:
# 	 INV_MEAN_MIN_DEPTH
# 	 NUM_AS_ROOT
# 	 SUM_SCORE
# 	 NUM_NODES

# %% [markdown]
# Feature inside important variables:
#
# The larger the importance score for NUM_AS_ROOT, the more impact it has on the outcome of the model.

# %%
inspector.variable_importances()["NUM_AS_ROOT"]
# Out:
# [("OverallQual" (1; #62), 121.0),
#  ("Neighborhood" (4; #59), 39.0),
#  ("ExterQual" (4; #22), 36.0),
#  ("GarageCars" (1; #32), 36.0),
#  ("GrLivArea" (1; #38), 22.0),
#  ("BsmtQual" (4; #14), 12.0),
#  ("GarageArea" (1; #31), 9.0),
#  ("TotalBsmtSF" (1; #73), 9.0),
#  ("YearBuilt" (1; #76), 9.0),
#  ("KitchenQual" (4; #44), 4.0),
#  ("GarageYrBlt" (1; #37), 2.0),
#  ("1stFlrSF" (1; #0), 1.0)]

# %%
plt.figure(figsize=(12, 4))

# Mean decrease in AUC of the class 1 vs the others.
variable_importance_metric = "NUM_AS_ROOT"
variable_importances = inspector.variable_importances()[variable_importance_metric]

# Extract the feature name and importance values.
#
# `variable_importances` is a list of <feature, importance> tuples.
feature_names = [vi[0].name for vi in variable_importances]
feature_importances = [vi[1] for vi in variable_importances]
# The feature are ordered in decreasing importance value.
feature_ranks = range(len(feature_names))

bar = plt.barh(feature_ranks, feature_importances, label=[str(x) for x in feature_ranks])
plt.yticks(feature_ranks, feature_names)
plt.gca().invert_yaxis()

# TODO: Replace with "plt.bar_label()" when available.
# Label each bar with values
for importance, patch in zip(feature_importances, bar.patches):
  plt.text(patch.get_x() + patch.get_width(), patch.get_y(), f"{importance:.4f}", va="top")

plt.xlabel(variable_importance_metric)
plt.title("NUM AS ROOT of the class 1 vs the others")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Test Evaluation

# %%
test_df = pd.read_csv("test.csv")
ids = test_df.pop('Id')

test_ds_tf = tfdf.keras.pd_dataframe_to_tf_dataset(
    test_df,
    task = tfdf.keras.Task.REGRESSION)

preds = rf.predict(test_ds_tf)
output = pd.DataFrame({'Id': ids,
                       'SalePrice': preds.squeeze()})

evaluation_test = rf.evaluate(x=test_ds_tf,return_dict=True)

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")

output.head()
# Out:
# 2023-05-28 23:02:54.079098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_20' with dtype int64 and shape [1459]
# 	 [[{{node Placeholder/_20}}]]
# ...
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0000e+00 - mse: 0.0000e+00
# loss: 0.0000
# mse: 1061600896.0000
#      Id      SalePrice
# 0  1461  129047.359375
# 1  1462  154276.687500
# 2  1463  184493.656250
# 3  1464  184272.281250
# 4  1465  199853.750000

# %%
sample_submission_df = pd.read_csv('sample_submission.csv')
sample_submission_df['SalePrice'] = rf.predict(test_ds_tf)
sample_submission_df.to_csv('sample_submitted.csv', index=False)
sample_submission_df.head()
# Out:
# 2/2 [==============================] - 0s 20ms/step
#      Id      SalePrice
# 0  1461  129047.359375
# 1  1462  154276.687500
# 2  1463  184493.656250
# 3  1464  184272.281250
# 4  1465  199853.750000
